# %% [markdown]
# # Research Ireland RFD Dataset
# ![ResearchIreland](https://media.researchireland.ie/wp-content/uploads/2026/01/Research_Ireland_RGB_logo_green-1.jpg)
# ###### *“Logo provided by Research Ireland and used in line with the Research Ireland brand guidelines”*

# %% [markdown]
# Formed from a merger of Science Foundation Ireland and the Irish Research Council, Research Ireland is Ireland's largest national research funding agency. It supports curiosity-driven and applied research across all disciplines and career levels and supports a wide range of different research funding initiatives, from enterprise-led funding programmes to STEM educational initatives.
#
# The dataset produced below includes all the grants funded by Research Ireland since the organisation's launch in 2024 and was produced using the data Research Ireland provides as part of its annual open data publication: https://www.researchireland.ie/about-us/governance-policies/open-data/.

# %% [markdown]
# ## Import Libraries
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from functions import clean_currency
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[70], line 5
#       3 import matplotlib.pyplot as plt
#       4 import datetime as dt
# ----> 5 from functions import clean
#
# ImportError: cannot import name 'clean' from 'functions' (/workspaces/rf-database/functions.py)

# %% [markdown]
# ## Preping the dataset
# ---

# %% [markdown]
# First we need to pull down the data from Research Ireland's website

# %%
url = "https://media.researchireland.ie/wp-content/uploads/2026/04/Research-Ireland-Grant-Commitments-to-January-2026-09.04.26.csv"
ri = pd.read_csv(url, encoding="cp1252")
ri.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1206 entries, 0 to 1205
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Project ID         1206 non-null   str
#  1   Programme Name     1206 non-null   str
#  2   Lead Applicant     1206 non-null   str
#  3   ORCID ID           1165 non-null   str
#  4   Research Body      1206 non-null   str
#  5   Funder Name        1206 non-null   str
#  6   Funder ROR ID      1206 non-null   str
#  7   Project title      1205 non-null   str
#  8   Actual Start Date  1206 non-null   str
#  9   Final End Date     1206 non-null   str
#  10  Award Amount       1206 non-null   str
# dtypes: str(11)
# memory usage: 103.8 KB

# %% [markdown]
# Next, we're going to want to adjust some of the formatting of some of these fields to make them easier to analyse. That includes changing Actual Start Date and Final End Date so that they are formatted as dates instead of strings and Award Amount so that it is a interger.

# %%
# Convert dates to datetime
ri['Actual Start Date'] = pd.to_datetime(ri['Actual Start Date'])
ri['Final End Date'] = pd.to_datetime(ri['Final End Date'])
ri['Award Amount'] = clean(ri['Award Amount'])
ri.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 4
#       2 ri['Actual Start Date'] = pd.to_datetime(ri['Actual Start Date'])
#       3 ri['Final End Date'] = pd.to_datetime(ri['Final End Date'])
# ----> 4 ri['Award Amount'] = clean_currency(ri['Award Amount'])
#       5 ri.info()
#
# File /workspaces/rf-database/functions.py:7, in clean_currency(series)
#       1 def clean_currency(series):
#       2     return (series
#       3             .str.replace('€', '', regex=False)
#       4             .str.replace('£', '', regex=False)
#       5             .str.replace(',', '', regex=False)
#       6             .str.strip()
# ----> 7             .astype(float)
#       8             .astype(int))
#
# File ~/.python/current/lib/python3.12/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
# ...

# %%
ri['Award Amount'].head(10)
# Out:
# 0    1798675200000000
# 1    1798675200000000
# 2    1832889600000000
# 3    1830297600000000
# 4    1851292800000000
# 5    1872201600000000
# 6    1862784000000000
# 7    1778544000000000
# 8    1788220800000000
# 9    1788220800000000
# Name: Award Amount, dtype: int64
